# %%
# gpu check
# !nvidia-smi
# Out:
# Wed Jan 21 13:41:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# mount drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# clone github
import os, subprocess, textwrap, sys, pathlib

REPO_URL = "https://github.com/AmjadKudsi/Meta_llama-chatbot.git"
REPO_DIR = "/content/rag-chatbot"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # %cd {REPO_DIR}
    # !git pull

# %cd {REPO_DIR}
# Out:
# Cloning into '/content/rag-chatbot'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 35 (delta 10), reused 24 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 7.61 KiB | 7.61 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/rag-chatbot

# %%
# load yaml

import os
import yaml

CONFIG_PATH = "/content/rag-chatbot/configs/app.yaml"

with open(CONFIG_PATH, "r") as f:
    cfg = yaml.safe_load(f)

paths = cfg["paths"]

DOCS_DIR = paths["docs_dir"]
ARTIFACTS_DIR = paths["artifacts_dir"]
INDEX_DIR = paths["index_dir"]
EVAL_RUNS_DIR = paths["eval_runs_dir"]
TRACES_DIR = paths["traces_dir"]

for p in [INDEX_DIR, EVAL_RUNS_DIR, TRACES_DIR]:
    os.makedirs(p, exist_ok=True)

print("Loaded config from:", CONFIG_PATH)
print("DOCS_DIR:", DOCS_DIR)
print("INDEX_DIR:", INDEX_DIR)
print("EVAL_RUNS_DIR:", EVAL_RUNS_DIR)
# Out:
# Loaded config from: /content/rag-chatbot/configs/app.yaml
# DOCS_DIR: /content/drive/MyDrive/rag-chatbot/raw_docs
# INDEX_DIR: /content/drive/MyDrive/rag-chatbot/artifacts/indexes
# EVAL_RUNS_DIR: /content/drive/MyDrive/rag-chatbot/artifacts/eval_runs

# %%
# src package (skip)

#import sys
#sys.path.insert(0, "/content/rag-chatbot/src")

# %%
# sanity check

import os, glob

print("Notebooks:", len(glob.glob("/content/rag-chatbot/notebooks/*.ipynb")))
pdfs = glob.glob(DOCS_DIR + "/*.pdf")
print("PDFs found:", len(pdfs))
print("Example:", os.path.basename(pdfs[0]) if pdfs else "None")
# Out:
# Notebooks: 6
# PDFs found: 10
# Example: tax01.pdf
