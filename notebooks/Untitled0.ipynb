# %%
import platform, sys
print(platform.platform())
print(sys.executable)
# Out:
# Linux-6.6.105+-x86_64-with-glibc2.35
# /usr/bin/python3

# %%
# !nvidia-smi
# Out:
# Tue Jan 20 23:24:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install llama-index-embeddings-openai
# %pip install llama-index-llms-openai

# %%
# !pip install llama-index

# %%
from pathlib import Path

here = Path.cwd().resolve()
root = next((p for p in [here, *here.parents] if (p / ".git").exists()), None)
print("root:", root)

raw_docs = root / "data" / "raw_docs" if root else None
print("raw_docs:", raw_docs)
print("exists:", raw_docs.exists() if raw_docs else None)
# Out:
# root: None
# raw_docs: None
# exists: None

# %%
import os
from pathlib import Path

print("cwd:", os.getcwd())
print("cwd contents:", [p.name for p in Path.cwd().iterdir()][:30])
# Out:
# cwd: /content
# cwd contents: ['.config', 'sample_data']
